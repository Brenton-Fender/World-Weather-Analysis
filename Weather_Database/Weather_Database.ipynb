# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 727

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
            
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),'Country':city_country,
                          'Lat':city_lat,'Lng':city_lng,
                          'Max Temp':city_max_temp,'Humidity':city_humidity,
                          'Cloudiness':city_clouds,'Wind Speed':city_wind,
                          'Current Description':city_weather_description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | takoradi
# Processing Record 3 of Set 1 | cockburn town
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | huizhou
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | vostok
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | pilao arcado
# City not found. Skipping...
# Processing Record 14 of Set 1 | port blair
# Processing Record 15 of Set 1 | irbit
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | litovko
# Processing Record 18 of Set 1 | hojai
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 1 | draganesti-vlasca
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | chauny
# Processing Record 25 of Set 1 | emerald
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | tuatapere
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | sao joao da barra
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | bol
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | aden
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | caravelas
# Processing Record 39 of Set 1 | mahibadhoo
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | fukue
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | tahta
# Processing Record 48 of Set 1 | teguldet
# Processing Record 49 of Set 1 | ahipara
# Processing Record 50 of Set 1 | porto novo
# Processing Record 1 of Set 2 | naze
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | santa maria
# Processing Record 5 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | saint george
# Processing Record 7 of Set 2 | lagoa
# Processing Record 8 of Set 2 | sidney
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | olafsvik
# Processing Record 12 of Set 2 | tammisaari
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 2 | college
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | kloulklubed
# Processing Record 21 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 2 | dingle
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | alta gracia
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | kununurra
# Processing Record 29 of Set 2 | margate
# Processing Record 30 of Set 2 | norman wells
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | cuorgne
# Processing Record 33 of Set 2 | san quintin
# Processing Record 34 of Set 2 | laguna
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | hami
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | sabang
# Processing Record 41 of Set 2 | srednekolymsk
# Processing Record 42 of Set 2 | saint-augustin
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 47 of Set 2 | chapais
# Processing Record 48 of Set 2 | hutang
# Processing Record 49 of Set 2 | rusape
# Processing Record 50 of Set 2 | kahului
# Processing Record 1 of Set 3 | zaraza
# Processing Record 2 of Set 3 | loa janan
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | tapiramuta
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | williston
# Processing Record 8 of Set 3 | montrose
# Processing Record 9 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | basco
# Processing Record 12 of Set 3 | ormara
# Processing Record 13 of Set 3 | sabha
# Processing Record 14 of Set 3 | sisimiut
# Processing Record 15 of Set 3 | paralimni
# Processing Record 16 of Set 3 | dahanu
# Processing Record 17 of Set 3 | pacific grove
# Processing Record 18 of Set 3 | gizo
# Processing Record 19 of Set 3 | panguna
# Processing Record 20 of Set 3 | cabra
# Processing Record 21 of Set 3 | caconda
# Processing Record 22 of Set 3 | biltine
# Processing Record 23 of Set 3 | okhotsk
# Processing Record 24 of Set 3 | buraydah
# Processing Record 25 of Set 3 | dera bugti
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | ardistan
# City not found. Skipping...
# Processing Record 31 of Set 3 | garowe
# Processing Record 32 of Set 3 | klaksvik
# Processing Record 33 of Set 3 | zyryanka
# Processing Record 34 of Set 3 | kizema
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | tlaxiaco
# City not found. Skipping...
# Processing Record 37 of Set 3 | cascais
# Processing Record 38 of Set 3 | anito
# Processing Record 39 of Set 3 | funtua
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | vestmannaeyjar
# Processing Record 42 of Set 3 | dori
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | vestmanna
# Processing Record 45 of Set 3 | victoria
# Processing Record 46 of Set 3 | coihaique
# Processing Record 47 of Set 3 | bogalusa
# Processing Record 48 of Set 3 | nguru
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | solnechnyy
# Processing Record 1 of Set 4 | jinchang
# Processing Record 2 of Set 4 | hofn
# Processing Record 3 of Set 4 | vaini
# Processing Record 4 of Set 4 | san patricio
# Processing Record 5 of Set 4 | korla
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | bolshoye nagatkino
# Processing Record 8 of Set 4 | port moresby
# Processing Record 9 of Set 4 | flin flon
# Processing Record 10 of Set 4 | sinnamary
# Processing Record 11 of Set 4 | jurm
# Processing Record 12 of Set 4 | nikaia
# Processing Record 13 of Set 4 | los llanos de aridane
# Processing Record 14 of Set 4 | muros
# Processing Record 15 of Set 4 | maldonado
# Processing Record 16 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 4 | sangar
# Processing Record 18 of Set 4 | iberia
# Processing Record 19 of Set 4 | erzin
# Processing Record 20 of Set 4 | waiouru
# Processing Record 21 of Set 4 | liwale
# Processing Record 22 of Set 4 | mvangue
# Processing Record 23 of Set 4 | paragominas
# Processing Record 24 of Set 4 | chipiona
# Processing Record 25 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 4 | farmington
# Processing Record 27 of Set 4 | aktash
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | edd
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | puerto escondido
# Processing Record 32 of Set 4 | khatanga
# Processing Record 33 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 4 | kuli
# Processing Record 35 of Set 4 | vila velha
# Processing Record 36 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 4 | buin
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | banjar
# Processing Record 40 of Set 4 | winslow
# Processing Record 41 of Set 4 | gat
# Processing Record 42 of Set 4 | trairi
# Processing Record 43 of Set 4 | sembakung
# Processing Record 44 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | ikalamavony
# Processing Record 47 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 4 | ponta do sol
# Processing Record 49 of Set 4 | avarua
# Processing Record 50 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 5 | kaeo
# Processing Record 3 of Set 5 | ajdabiya
# Processing Record 4 of Set 5 | elliot lake
# Processing Record 5 of Set 5 | copperas cove
# Processing Record 6 of Set 5 | straldza
# City not found. Skipping...
# Processing Record 7 of Set 5 | vao
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | arona
# Processing Record 11 of Set 5 | baoning
# Processing Record 12 of Set 5 | cap malheureux
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | ugoofaaru
# Processing Record 15 of Set 5 | broome
# Processing Record 16 of Set 5 | shache
# Processing Record 17 of Set 5 | zhongshu
# Processing Record 18 of Set 5 | yulara
# Processing Record 19 of Set 5 | hammonton
# Processing Record 20 of Set 5 | narrabri
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | sainte-rose
# Processing Record 23 of Set 5 | goderich
# Processing Record 24 of Set 5 | sao felix do xingu
# Processing Record 25 of Set 5 | narasannapeta
# Processing Record 26 of Set 5 | tanout
# Processing Record 27 of Set 5 | peniche
# Processing Record 28 of Set 5 | san jose
# Processing Record 29 of Set 5 | ostrovnoy
# Processing Record 30 of Set 5 | aklavik
# Processing Record 31 of Set 5 | cesme
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | pandan
# Processing Record 34 of Set 5 | mwinilunga
# Processing Record 35 of Set 5 | lodja
# Processing Record 36 of Set 5 | alexandria
# Processing Record 37 of Set 5 | bonavista
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 5 | sivakasi
# Processing Record 41 of Set 5 | saint-philippe
# Processing Record 42 of Set 5 | la ronge
# Processing Record 43 of Set 5 | alofi
# Processing Record 44 of Set 5 | ruski krstur
# Processing Record 45 of Set 5 | puerto ayacucho
# Processing Record 46 of Set 5 | iqaluit
# Processing Record 47 of Set 5 | georgetown
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | ozinki
# Processing Record 50 of Set 5 | potosi
# Processing Record 1 of Set 6 | athabasca
# Processing Record 2 of Set 6 | limanowa
# Processing Record 3 of Set 6 | marawi
# Processing Record 4 of Set 6 | pangnirtung
# Processing Record 5 of Set 6 | daru
# Processing Record 6 of Set 6 | agva
# City not found. Skipping...
# Processing Record 7 of Set 6 | iskateley
# Processing Record 8 of Set 6 | zhifang
# Processing Record 9 of Set 6 | tevaitoa
# Processing Record 10 of Set 6 | kajaani
# Processing Record 11 of Set 6 | povenets
# Processing Record 12 of Set 6 | rayong
# Processing Record 13 of Set 6 | praia da vitoria
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | abu dhabi
# Processing Record 16 of Set 6 | mahajanga
# Processing Record 17 of Set 6 | salinopolis
# Processing Record 18 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 6 | evensk
# Processing Record 20 of Set 6 | upata
# Processing Record 21 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 23 of Set 6 | quang ngai
# Processing Record 24 of Set 6 | mount gambier
# Processing Record 25 of Set 6 | verkhnyaya inta
# Processing Record 26 of Set 6 | te anau
# Processing Record 27 of Set 6 | tisul
# Processing Record 28 of Set 6 | bintulu
# Processing Record 29 of Set 6 | belmonte
# Processing Record 30 of Set 6 | priekule
# Processing Record 31 of Set 6 | risor
# Processing Record 32 of Set 6 | namatanai
# Processing Record 33 of Set 6 | kodiak
# Processing Record 34 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 6 | fereydun kenar
# Processing Record 36 of Set 6 | ust-nera
# Processing Record 37 of Set 6 | amapa
# Processing Record 38 of Set 6 | pisco
# Processing Record 39 of Set 6 | russell
# Processing Record 40 of Set 6 | bathsheba
# Processing Record 41 of Set 6 | damghan
# Processing Record 42 of Set 6 | stirion
# Processing Record 43 of Set 6 | xiongshi
# City not found. Skipping...
# Processing Record 44 of Set 6 | whitehorse
# Processing Record 45 of Set 6 | rudnyy
# Processing Record 46 of Set 6 | leh
# Processing Record 47 of Set 6 | nemuro
# Processing Record 48 of Set 6 | inuvik
# Processing Record 49 of Set 6 | makasar
# Processing Record 50 of Set 6 | aykhal
# Processing Record 1 of Set 7 | alice springs
# Processing Record 2 of Set 7 | san andres
# Processing Record 3 of Set 7 | zhigansk
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | douentza
# Processing Record 6 of Set 7 | yerbogachen
# Processing Record 7 of Set 7 | half moon bay
# Processing Record 8 of Set 7 | dapa
# Processing Record 9 of Set 7 | qui nhon
# Processing Record 10 of Set 7 | ginir
# Processing Record 11 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 7 | messina
# Processing Record 13 of Set 7 | lorengau
# Processing Record 14 of Set 7 | port hardy
# Processing Record 15 of Set 7 | cidreira
# Processing Record 16 of Set 7 | great falls
# Processing Record 17 of Set 7 | neuquen
# Processing Record 18 of Set 7 | masallatah
# Processing Record 19 of Set 7 | xining
# Processing Record 20 of Set 7 | urucui
# Processing Record 21 of Set 7 | aswan
# Processing Record 22 of Set 7 | phibun mangsahan
# Processing Record 23 of Set 7 | torbay
# Processing Record 24 of Set 7 | buguruslan
# Processing Record 25 of Set 7 | skibbereen
# Processing Record 26 of Set 7 | altamira
# Processing Record 27 of Set 7 | puerto baquerizo moreno
# Processing Record 28 of Set 7 | port keats
# Processing Record 29 of Set 7 | usinsk
# Processing Record 30 of Set 7 | pevek
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | itacare
# Processing Record 33 of Set 7 | udachnyy
# Processing Record 34 of Set 7 | panaba
# Processing Record 35 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | itum-kale
# Processing Record 37 of Set 7 | rawson
# Processing Record 38 of Set 7 | ilulissat
# Processing Record 39 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 7 | harper
# Processing Record 41 of Set 7 | kattivakkam
# Processing Record 42 of Set 7 | pankrushikha
# Processing Record 43 of Set 7 | castro
# Processing Record 44 of Set 7 | montepuez
# Processing Record 45 of Set 7 | le port
# Processing Record 46 of Set 7 | nanma
# Processing Record 47 of Set 7 | waddan
# Processing Record 48 of Set 7 | grootfontein
# Processing Record 49 of Set 7 | araouane
# Processing Record 50 of Set 7 | nizhniy baskunchak
# Processing Record 1 of Set 8 | cairns
# Processing Record 2 of Set 8 | kamuli
# Processing Record 3 of Set 8 | san luis
# Processing Record 4 of Set 8 | abalak
# Processing Record 5 of Set 8 | culiacancito
# Processing Record 6 of Set 8 | bonnyville
# Processing Record 7 of Set 8 | kieta
# Processing Record 8 of Set 8 | atambua
# Processing Record 9 of Set 8 | oranjemund
# Processing Record 10 of Set 8 | pangkalanbuun
# Processing Record 11 of Set 8 | hasilpur
# Processing Record 12 of Set 8 | marsh harbour
# Processing Record 13 of Set 8 | clyde river
# Processing Record 14 of Set 8 | isangel
# Processing Record 15 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 8 | sept-iles
# Processing Record 17 of Set 8 | tucumcari
# Processing Record 18 of Set 8 | asasa
# Processing Record 19 of Set 8 | itarema
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | gazanjyk
# Processing Record 23 of Set 8 | lata
# Processing Record 24 of Set 8 | sakai
# Processing Record 25 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 26 of Set 8 | bilma
# Processing Record 27 of Set 8 | bandarbeyla
# Processing Record 28 of Set 8 | omsukchan
# Processing Record 29 of Set 8 | roebourne
# Processing Record 30 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 8 | fare
# Processing Record 32 of Set 8 | kismayo
# Processing Record 33 of Set 8 | oxelosund
# Processing Record 34 of Set 8 | yakeshi
# Processing Record 35 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 8 | saint-pierre
# Processing Record 37 of Set 8 | tilichiki
# Processing Record 38 of Set 8 | muhos
# Processing Record 39 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 8 | nynashamn
# Processing Record 41 of Set 8 | marzuq
# Processing Record 42 of Set 8 | rio gallegos
# Processing Record 43 of Set 8 | chambar
# Processing Record 44 of Set 8 | mao
# Processing Record 45 of Set 8 | nioro
# Processing Record 46 of Set 8 | walvis bay
# Processing Record 47 of Set 8 | haines junction
# Processing Record 48 of Set 8 | talnakh
# Processing Record 49 of Set 8 | seka
# Processing Record 50 of Set 8 | qaqortoq
# Processing Record 1 of Set 9 | antofagasta
# Processing Record 2 of Set 9 | wanaka
# Processing Record 3 of Set 9 | yatou
# Processing Record 4 of Set 9 | san buenaventura
# Processing Record 5 of Set 9 | san carlos
# Processing Record 6 of Set 9 | kupang
# Processing Record 7 of Set 9 | orzu
# Processing Record 8 of Set 9 | kitimat
# Processing Record 9 of Set 9 | pirovskoye
# Processing Record 10 of Set 9 | sillod
# Processing Record 11 of Set 9 | svetlogorsk
# Processing Record 12 of Set 9 | port hedland
# Processing Record 13 of Set 9 | porto nacional
# Processing Record 14 of Set 9 | gobabis
# Processing Record 15 of Set 9 | aanekoski
# Processing Record 16 of Set 9 | pasni
# Processing Record 17 of Set 9 | kenai
# Processing Record 18 of Set 9 | beloha
# Processing Record 19 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 20 of Set 9 | brae
# Processing Record 21 of Set 9 | inhambane
# Processing Record 22 of Set 9 | da nang
# Processing Record 23 of Set 9 | port hawkesbury
# Processing Record 24 of Set 9 | souillac
# Processing Record 25 of Set 9 | talaya
# Processing Record 26 of Set 9 | grantham
# Processing Record 27 of Set 9 | chestermere
# Processing Record 28 of Set 9 | galesong
# Processing Record 29 of Set 9 | berlevag
# Processing Record 30 of Set 9 | hereford
# Processing Record 31 of Set 9 | hambantota
# Processing Record 32 of Set 9 | abu samrah
# Processing Record 33 of Set 9 | jales
# Processing Record 34 of Set 9 | rovaniemi
# Processing Record 35 of Set 9 | kruisfontein
# Processing Record 36 of Set 9 | tombouctou
# Processing Record 37 of Set 9 | severo-kurilsk
# Processing Record 38 of Set 9 | plettenberg bay
# Processing Record 39 of Set 9 | samoded
# Processing Record 40 of Set 9 | mackay
# Processing Record 41 of Set 9 | port lincoln
# Processing Record 42 of Set 9 | chernyshevskiy
# Processing Record 43 of Set 9 | acapulco
# Processing Record 44 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 45 of Set 9 | oksfjord
# Processing Record 46 of Set 9 | ulladulla
# Processing Record 47 of Set 9 | wagar
# Processing Record 48 of Set 9 | manali
# Processing Record 49 of Set 9 | baykit
# Processing Record 50 of Set 9 | boende
# Processing Record 1 of Set 10 | bonfim
# Processing Record 2 of Set 10 | belyy yar
# Processing Record 3 of Set 10 | bayji
# Processing Record 4 of Set 10 | kurumkan
# Processing Record 5 of Set 10 | flinders
# Processing Record 6 of Set 10 | taoudenni
# Processing Record 7 of Set 10 | vanavara
# Processing Record 8 of Set 10 | hamilton
# Processing Record 9 of Set 10 | adamovka
# Processing Record 10 of Set 10 | tshikapa
# Processing Record 11 of Set 10 | khasan
# Processing Record 12 of Set 10 | lossiemouth
# Processing Record 13 of Set 10 | saint anthony
# Processing Record 14 of Set 10 | itaquyry
# Processing Record 15 of Set 10 | nelson bay
# Processing Record 16 of Set 10 | mastic beach
# Processing Record 17 of Set 10 | constitucion
# Processing Record 18 of Set 10 | sola
# Processing Record 19 of Set 10 | savannah bight
# Processing Record 20 of Set 10 | ewa beach
# Processing Record 21 of Set 10 | havre-saint-pierre
# Processing Record 22 of Set 10 | nome
# Processing Record 23 of Set 10 | fareham
# Processing Record 24 of Set 10 | orlik
# Processing Record 25 of Set 10 | soe
# Processing Record 26 of Set 10 | lima
# Processing Record 27 of Set 10 | norsup
# Processing Record 28 of Set 10 | artyom
# Processing Record 29 of Set 10 | kennett
# Processing Record 30 of Set 10 | sobolevo
# Processing Record 31 of Set 10 | revelstoke
# Processing Record 32 of Set 10 | nouadhibou
# Processing Record 33 of Set 10 | batagay-alyta
# Processing Record 34 of Set 10 | celina
# Processing Record 35 of Set 10 | dargaville
# Processing Record 36 of Set 10 | marsaxlokk
# Processing Record 37 of Set 10 | vila franca do campo
# Processing Record 38 of Set 10 | buritizeiro
# Processing Record 39 of Set 10 | glendive
# Processing Record 40 of Set 10 | ures
# Processing Record 41 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 10 | manzanillo
# Processing Record 43 of Set 10 | galle
# Processing Record 44 of Set 10 | portland
# Processing Record 45 of Set 10 | carballo
# Processing Record 46 of Set 10 | rocha
# Processing Record 47 of Set 10 | tournon-sur-rhone
# Processing Record 48 of Set 10 | olinda
# Processing Record 49 of Set 10 | sao miguel do araguaia
# Processing Record 50 of Set 10 | ust-omchug
# Processing Record 1 of Set 11 | asau
# Processing Record 2 of Set 11 | velikodvorskiy
# Processing Record 3 of Set 11 | leningradskiy
# Processing Record 4 of Set 11 | ust-kut
# Processing Record 5 of Set 11 | ampanihy
# Processing Record 6 of Set 11 | arroyo
# Processing Record 7 of Set 11 | zabaykalsk
# Processing Record 8 of Set 11 | riyadh
# Processing Record 9 of Set 11 | maragogi
# Processing Record 10 of Set 11 | quesnel
# Processing Record 11 of Set 11 | den helder
# Processing Record 12 of Set 11 | matagami
# Processing Record 13 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 11 | ballina
# Processing Record 15 of Set 11 | ngunguru
# Processing Record 16 of Set 11 | newcastleton
# Processing Record 17 of Set 11 | noumea
# Processing Record 18 of Set 11 | sidrolandia
# Processing Record 19 of Set 11 | kortkeros
# Processing Record 20 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 11 | lasa
# Processing Record 22 of Set 11 | parva
# Processing Record 23 of Set 11 | burns lake
# Processing Record 24 of Set 11 | santa ines
# Processing Record 25 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 26 of Set 11 | dolores
# Processing Record 27 of Set 11 | two hills
# Processing Record 28 of Set 11 | kibaya
# Processing Record 29 of Set 11 | shorapur
# Processing Record 30 of Set 11 | vysokogornyy
# Processing Record 31 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 33 of Set 11 | saint-paul
# Processing Record 34 of Set 11 | pyapon
# Processing Record 35 of Set 11 | sao filipe
# Processing Record 36 of Set 11 | karpogory
# Processing Record 37 of Set 11 | yenotayevka
# Processing Record 38 of Set 11 | lahij
# Processing Record 39 of Set 11 | eureka
# Processing Record 40 of Set 11 | cumbum
# Processing Record 41 of Set 11 | stokmarknes
# Processing Record 42 of Set 11 | along
# Processing Record 43 of Set 11 | teacapan
# Processing Record 44 of Set 11 | tual
# Processing Record 45 of Set 11 | lokhvytsya
# Processing Record 46 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 11 | ratnagiri
# Processing Record 48 of Set 11 | santa cruz
# Processing Record 49 of Set 11 | uni
# Processing Record 50 of Set 11 | meulaboh
# Processing Record 1 of Set 12 | mayor pablo lagerenza
# Processing Record 2 of Set 12 | karratha
# Processing Record 3 of Set 12 | pimenteiras
# Processing Record 4 of Set 12 | the valley
# Processing Record 5 of Set 12 | esfarayen
# Processing Record 6 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 12 | khani
# Processing Record 8 of Set 12 | dudinka
# Processing Record 9 of Set 12 | bela
# Processing Record 10 of Set 12 | road town
# Processing Record 11 of Set 12 | ancud
# Processing Record 12 of Set 12 | odda
# Processing Record 13 of Set 12 | hobyo
# Processing Record 14 of Set 12 | nanortalik
# Processing Record 15 of Set 12 | san policarpo
# Processing Record 16 of Set 12 | alekseyevka
# Processing Record 17 of Set 12 | san ramon de la nueva oran
# Processing Record 18 of Set 12 | metes
# Processing Record 19 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 21 of Set 12 | mahon
# Processing Record 22 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 12 | dunedin
# Processing Record 24 of Set 12 | nyurba
# Processing Record 25 of Set 12 | mandalgovi
# Processing Record 26 of Set 12 | taltal
# Processing Record 27 of Set 12 | lengshuitan
# Processing Record 28 of Set 12 | mathbaria
# Processing Record 29 of Set 12 | shingu
# Processing Record 30 of Set 12 | akyab
# Processing Record 31 of Set 12 | puerto del rosario
# Processing Record 32 of Set 12 | suhindol
# Processing Record 33 of Set 12 | matamoros
# Processing Record 34 of Set 12 | lazaro cardenas
# Processing Record 35 of Set 12 | damara
# Processing Record 36 of Set 12 | auki
# Processing Record 37 of Set 12 | mercedes
# Processing Record 38 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 12 | teya
# Processing Record 40 of Set 12 | avanigadda
# Processing Record 41 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 12 | broken hill
# Processing Record 43 of Set 12 | dodge city
# Processing Record 44 of Set 12 | leshukonskoye
# Processing Record 45 of Set 12 | namibe
# Processing Record 46 of Set 12 | bassar
# Processing Record 47 of Set 12 | taveta
# Processing Record 48 of Set 12 | trelew
# Processing Record 49 of Set 12 | payo
# Processing Record 50 of Set 12 | katangli
# Processing Record 1 of Set 13 | gorno-altaysk
# Processing Record 2 of Set 13 | beringovskiy
# Processing Record 3 of Set 13 | bronkhorstspruit
# Processing Record 4 of Set 13 | nhulunbuy
# Processing Record 5 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 13 | pemangkat
# Processing Record 7 of Set 13 | kasongo
# Processing Record 8 of Set 13 | vanimo
# Processing Record 9 of Set 13 | nipawin
# Processing Record 10 of Set 13 | balkanabat
# Processing Record 11 of Set 13 | parrita
# Processing Record 12 of Set 13 | oranjestad
# Processing Record 13 of Set 13 | zyryanovsk
# Processing Record 14 of Set 13 | jambi
# Processing Record 15 of Set 13 | kabinda
# Processing Record 16 of Set 13 | changji
# Processing Record 17 of Set 13 | akdepe
# Processing Record 18 of Set 13 | kiruna
# Processing Record 19 of Set 13 | umm lajj
# Processing Record 20 of Set 13 | cuamba
# Processing Record 21 of Set 13 | sistranda
# Processing Record 22 of Set 13 | ashqelon
# Processing Record 23 of Set 13 | nuuk
# Processing Record 24 of Set 13 | yeniseysk
# Processing Record 25 of Set 13 | masuguru
# Processing Record 26 of Set 13 | mehamn
# Processing Record 27 of Set 13 | egvekinot
# Processing Record 28 of Set 13 | ayios kirikos
# City not found. Skipping...
# Processing Record 29 of Set 13 | itaituba
# Processing Record 30 of Set 13 | truth or consequences
# Processing Record 31 of Set 13 | dali
# Processing Record 32 of Set 13 | yar-sale
# Processing Record 33 of Set 13 | manhattan
# Processing Record 34 of Set 13 | mount isa
# Processing Record 35 of Set 13 | stephenville
# Processing Record 36 of Set 13 | port macquarie
# Processing Record 37 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 13 | ostersund
# Processing Record 39 of Set 13 | dongsheng
# Processing Record 40 of Set 13 | augusto correa
# Processing Record 41 of Set 13 | mookane
# Processing Record 42 of Set 13 | tromso
# Processing Record 43 of Set 13 | caico
# Processing Record 44 of Set 13 | springfield
# Processing Record 45 of Set 13 | husavik
# Processing Record 46 of Set 13 | obo
# Processing Record 47 of Set 13 | faya
# Processing Record 48 of Set 13 | bata
# Processing Record 49 of Set 13 | puerto el triunfo
# Processing Record 50 of Set 13 | grindavik
# Processing Record 1 of Set 14 | lensk
# Processing Record 2 of Set 14 | askino
# Processing Record 3 of Set 14 | kholtoson
# Processing Record 4 of Set 14 | kushiro
# Processing Record 5 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 14 | ketchikan
# Processing Record 7 of Set 14 | north bend
# Processing Record 8 of Set 14 | yefira
# City not found. Skipping...
# Processing Record 9 of Set 14 | turukhansk
# Processing Record 10 of Set 14 | coquimbo
# Processing Record 11 of Set 14 | erenhot
# Processing Record 12 of Set 14 | waingapu
# Processing Record 13 of Set 14 | kanniyakumari
# Processing Record 14 of Set 14 | bojnurd
# Processing Record 15 of Set 14 | puerto cortes
# City not found. Skipping...
# Processing Record 16 of Set 14 | makakilo city
# Processing Record 17 of Set 14 | lashio
# Processing Record 18 of Set 14 | kamaishi
# Processing Record 19 of Set 14 | taseyevo
# Processing Record 20 of Set 14 | kungurtug
# Processing Record 21 of Set 14 | samarai
# Processing Record 22 of Set 14 | toamasina
# Processing Record 23 of Set 14 | marfino
# Processing Record 24 of Set 14 | daura
# Processing Record 25 of Set 14 | sakakah
# Processing Record 26 of Set 14 | vagur
# Processing Record 27 of Set 14 | zhezkazgan
# Processing Record 28 of Set 14 | hegang
# Processing Record 29 of Set 14 | vila
# Processing Record 30 of Set 14 | eyemouth
# Processing Record 31 of Set 14 | nalut
# Processing Record 32 of Set 14 | hualmay
# Processing Record 33 of Set 14 | reforma
# Processing Record 34 of Set 14 | dalvik
# Processing Record 35 of Set 14 | belaya gora
# Processing Record 36 of Set 14 | asfi
# Processing Record 37 of Set 14 | rajur
# Processing Record 38 of Set 14 | gerede
# Processing Record 39 of Set 14 | matara
# Processing Record 40 of Set 14 | ames
# Processing Record 41 of Set 14 | aripuana
# Processing Record 42 of Set 14 | monroe
# Processing Record 43 of Set 14 | jumla
# Processing Record 44 of Set 14 | morehead
# Processing Record 45 of Set 14 | felidhoo
# City not found. Skipping...
# Processing Record 46 of Set 14 | impfondo
# Processing Record 47 of Set 14 | jiazi
# Processing Record 48 of Set 14 | polyany
# Processing Record 49 of Set 14 | rongcheng
# Processing Record 50 of Set 14 | menongue
# Processing Record 1 of Set 15 | mitsamiouli
# Processing Record 2 of Set 15 | tiznit
# Processing Record 3 of Set 15 | abbeville
# Processing Record 4 of Set 15 | ambanja
# Processing Record 5 of Set 15 | zilupe
# Processing Record 6 of Set 15 | tateyama
# Processing Record 7 of Set 15 | botwood
# Processing Record 8 of Set 15 | lamu
# Processing Record 9 of Set 15 | morros
# Processing Record 10 of Set 15 | kyra
# Processing Record 11 of Set 15 | cibitoke
# Processing Record 12 of Set 15 | surt
# Processing Record 13 of Set 15 | naryan-mar
# Processing Record 14 of Set 15 | ayagoz
# Processing Record 15 of Set 15 | kushima
# Processing Record 16 of Set 15 | avera
# Processing Record 17 of Set 15 | kalanchak
# Processing Record 18 of Set 15 | tessalit
# Processing Record 19 of Set 15 | coxim
# Processing Record 20 of Set 15 | neiafu
# Processing Record 21 of Set 15 | baoshan
# Processing Record 22 of Set 15 | tezu
# Processing Record 23 of Set 15 | havelock
# Processing Record 24 of Set 15 | kasiri
# Processing Record 25 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 15 | adrar
# Processing Record 27 of Set 15 | altea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 665

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hermanus      ZA -34.4187   19.2345     61.81        79          17
# 1       Takoradi      GH   4.8845   -1.7554     78.12        83          70
# 2  Cockburn Town      TC  21.4612  -71.1419     81.37        71          31
# 3   Puerto Ayora      EC  -0.7393  -90.3518     69.55        85          54
# 4         Albany      US  42.6001  -73.9662     28.81        81          28
# 5         Atuona      PF  -9.8000 -139.0333     77.68        75           3
# 6           Hilo      US  19.7297 -155.0900     74.93        84         100
# 7        Rikitea      PF -23.1203 -134.9692     74.34        84         100
# 8        Huizhou      CN  23.0833  114.4000     81.14        63         100
# 9         Vostok      RU  46.4856  135.8833     25.34        57          16
#
#    Wind Speed Current Description
# 0       13.11          few clouds
# 1        6.35       broken clouds
# 2       13.40    scattered clouds
# 3        4.00       broken clouds
# 4        3.65    scattered clouds
# 5       16.22           clear sky
# 6        6.91       moderate rain
# 7       13.47     overcast clouds
# 8        2.53     overcast clouds
# 9        5.21          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df.loc[:, column_order]

# Display sample data
city_data_df
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hermanus      ZA -34.4187  19.2345     61.81        79          17
# 1         Takoradi      GH   4.8845  -1.7554     78.12        83          70
# 2    Cockburn Town      TC  21.4612 -71.1419     81.37        71          31
# 3     Puerto Ayora      EC  -0.7393 -90.3518     69.55        85          54
# 4           Albany      US  42.6001 -73.9662     28.81        81          28
# ..             ...     ...      ...      ...       ...       ...         ...
# 660           Tezu      IN  27.9167  96.1667     78.33        29           0
# 661       Havelock      US  34.8791 -76.9013     52.93        88           0
# 662         Kasiri      SL   8.9412 -13.1148     77.16        85          94
# 663          Adrar      MR  20.5022 -10.0711     72.79        27          66
# 664          Altea      ES  38.5989  -0.0514     68.79        60          75
#
#      Wind Speed Current Description
# 0         13.11          few clouds
# 1          6.35       broken clouds
# 2         13.40    scattered clouds
# 3          4.00       broken clouds
# 4          3.65    scattered clouds
# ..          ...                 ...
# 660        3.38           clear sky
# 661        9.22           clear sky
# 662        2.98          light rain
# 663       10.49       broken clouds
# 664        7.67       broken clouds
#
# [665 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
